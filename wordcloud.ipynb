# %% [markdown]
# # Картина дня в облаке тегов

# %%
from myrsslib import *
import sqlite3
from wordcloud import WordCloud
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
# %matplotlib inline

path_to_db = 'news.db'
conn = sqlite3.connect(path_to_db)
c = conn.cursor()

c.execute("""SELECT time, title FROM titles
            ORDER BY time DESC
            LIMIT 900""")

titles, times = [], []
for time, title in c.fetchall():
    titles.append(title)
    times.append(time)

# STOPWORDS
russian_stopwords = stopwords.words("russian")
more_stopwords = ['Россия','России','году','года', 'власти', 'заявили','заявил','области','рф',
     'августа', 'тыс','млн','млрд','рублей','это','около','человек','число']

# Wordcloud
wordcloud = WordCloud(max_words=50, stopwords=russian_stopwords+more_stopwords, background_color='white')
wordcloud.generate(' '.join(titles))

plt.figure(figsize=(12, 18))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## Поэтапное создание:

# %%
path_to_db = 'news.db'
conn = sqlite3.connect(path_to_db)
c = conn.cursor()

# %%
c.execute("""SELECT time, title FROM titles
            ORDER BY time DESC
            LIMIT 1000""")

titles, times = [], []
for time, title in c.fetchall():
    titles.append(title)
    times.append(time)

# %% [markdown]
# Подготовка списка стопслов на русском.

# %%
# import nltk
# nltk.download('stopwords')

# %%
russian_stopwords = stopwords.words("russian")
' '.join(russian_stopwords)
# Out:
# 'и в во не что он на я с со как а то все она так его но да ты к у же вы за бы по только ее мне было вот от меня еще нет о из ему теперь когда даже ну вдруг ли если уже или ни быть был него до вас нибудь опять уж вам ведь там потом себя ничего ей может они тут где есть надо ней для мы тебя их чем была сам чтоб без будто чего раз тоже себе под будет ж тогда кто этот того потому этого какой совсем ним здесь этом один почти мой тем чтобы нее сейчас были куда зачем всех никогда можно при наконец два об другой хоть после над больше тот через эти нас про всего них какая много разве три эту моя впрочем хорошо свою этой перед иногда лучше чуть том нельзя такой им более всегда конечно всю между'

# %%
more_stopwords = ['году','года']

# %%
wordcloud = WordCloud(max_words=50, stopwords=russian_stopwords+more_stopwords, background_color='white').generate(content)

# %%
plt.figure(figsize=(12, 18))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
